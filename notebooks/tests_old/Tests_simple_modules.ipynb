# %% [markdown]
# # Gaussian

# %%
from src.supervised_gcal.layers.modules.simple import *

# %%
in_features = 25**2
out_features = 5**2
gaussian_linear = GaussianLinear(in_features, out_features, sigma=5)

# %%
gaussian_linear.weight.shape

# %%
from src.utils.images import *

# %%
gauss_size = int(in_features**0.5)
gauss = gaussian_generator(gauss_size, gauss_size//2, gauss_size//2, 1, 1, 0)
plot_matrix(gauss)

# %%
inp = torch.autograd.Variable(torch.from_numpy(gauss).view(in_features))

# %%
plot_matrix(tensor_to_numpy_matrix(gaussian_linear(inp).data, (50, 50)))

# %%
from src.supervised_gcal.utils.images import *

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 12))
plot_layer_weights(gaussian_linear)

# %% [markdown]
# # CloudGaussian

# %%
from src.supervised_gcal.layers.modules.simple import *

# %%
in_features = 25**2
out_features = 5**2
gaussian_cloud_linear = GaussianCloudLinear(in_features, out_features, sigma=5)

# %%
gaussian_cloud_linear.weight.shape
# Out:
# torch.Size([25, 625])

# %%
from src.utils.images import *

# %%
gauss_size = int(in_features**0.5)
gauss = gaussian_generator(gauss_size, gauss_size//2, gauss_size//2, 1, 1, 0)
plot_matrix(gauss)

# %%
inp = torch.autograd.Variable(torch.from_numpy(gauss).view(in_features))

# %%
plot_matrix(tensor_to_numpy_matrix(gaussian_cloud_linear(inp).data, (50, 50)))

# %%
from src.supervised_gcal.utils.images import *

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 12))
plot_layer_weights(gaussian_cloud_linear)

# %% [markdown]
# # DoG

# %%
from src.supervised_gcal.layers.modules.simple import *

# %%
in_features = 20**2
out_features = 5**2
gaussian_linear = DifferenceOfGaussiansLinear(in_features, out_features, on=True, sigma_surround=2)

# %%
from src.utils.images import *

# %%
gauss_size = int(in_features**0.5)
gauss = gaussian_generator(gauss_size, gauss_size//2, gauss_size//2, 1, 1, 0)
plot_matrix(gauss)

# %%
inp = torch.autograd.Variable(torch.from_numpy(gauss).view(in_features))

# %%
plot_matrix(tensor_to_numpy_matrix(gaussian_linear(inp).data, (50, 50)))

# %%
from src.supervised_gcal.utils.images import *

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 12))
plot_layer_weights(gaussian_linear)

# %% [markdown]
# # Piecewise Sigmoid

# %%
from src.supervised_gcal.layers.modules.simple import *

# %%
pw_sigmoid = PiecewiseSigmoid(min_theta=4, max_theta=9)

# %%
inputs = [torch.Tensor([i]) for i in range(0, 11)]

# %%
activations = [pw_sigmoid(i) for i in inputs]

# %%
import matplotlib.pyplot as plt
plt.plot([a.numpy() for a in activations])
plt.show()

# %%
pw_sigmoid = PiecewiseSigmoid(min_theta=0.4, max_theta=0.9)

# %%
import numpy as np
inputs = [torch.Tensor([i]) for i in np.linspace(0, 1, 11)]

# %%
activations = [pw_sigmoid(i) for i in inputs]

# %%
import matplotlib.pyplot as plt
plt.plot([a.numpy() for a in activations])
plt.show()
